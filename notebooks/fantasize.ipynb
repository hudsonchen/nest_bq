# %%
import torch
from botorch.models import SingleTaskGP
from botorch.models.transforms import Standardize
from botorch.acquisition import qExpectedImprovement
from botorch.sampling import SobolQMCNormalSampler, IIDNormalSampler
from botorch.optim import optimize_acqf
from botorch.fit import fit_gpytorch_model
from gpytorch.mlls import ExactMarginalLogLikelihood

# Step 1: Generate sample training data
train_X = torch.rand(10, 1) * 10  # 10 data points in 1D space
train_Y = torch.sin(train_X) + 0.2 * torch.randn_like(train_X)

# Step 2: Define and fit a GP model
gp_model = SingleTaskGP(train_X, train_Y, outcome_transform=Standardize(m=1))
mll = ExactMarginalLogLikelihood(gp_model.likelihood, gp_model)
fit_gpytorch_model(mll)

# Step 3: Define the candidate points for one-step look-ahead
X = torch.rand(20, 1) * 10  # 20 candidate points to fantasize on

# Step 4: Create fantasy scenarios with `fantasize`
# Configure the sampler for generating 1 fantasy samples
sampler = SobolQMCNormalSampler(sample_shape=1)  # num_fantasies = 10

# Generate fantasy model using the candidate points
fantasy_model = gp_model.fantasize(X[:, None, :], sampler=sampler, observation_noise=False)  # fantasy_model.train_targets will have shape (20, 1, 1)

# Step 5: Find the best target (max value) across fantasies for one-step EI
best_f = fantasy_model.train_targets.max(dim=-1)[0]  # shape: (20,)

# Step 6: Define the one-step Expected Improvement (EI) under the fantasized model
# Here we use `qExpectedImprovement` for the fantasized model
one_step_ei = qExpectedImprovement(model=fantasy_model, best_f=best_f)

# Step 7: Optimize the acquisition function to select the next best candidate
bounds = torch.tensor([[0.0], [10.0]])  # Define bounds for optimization
candidate, acq_value = optimize_acqf(
    acq_function=one_step_ei,
    bounds=bounds,
    q=1,  # Choosing 1 point for the next evaluation
    num_restarts=5,
    raw_samples=20,
)

print("Next candidate point for evaluation:", candidate)
print("Acquisition value:", acq_value)
# Out:
# /home/zongchen/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/models/gpytorch.py:129: UserWarning: The model inputs are of type torch.float32. It is strongly recommended to use double precision in BoTorch, as this improves both precision and stability and can help avoid numerical errors. See https://github.com/pytorch/botorch/discussions/1444
#   warnings.warn(_get_single_precision_warning(X.dtype), UserWarning)
# /home/zongchen/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/models/utils/assorted.py:173: InputDataWarning: Input data is not contained to the unit cube. Please consider min-max scaling the input data.
#   warnings.warn(msg, InputDataWarning)
# /home/zongchen/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/models/gpytorch.py:106: BotorchTensorDimensionWarning: Non-strict enforcement of botorch tensor conventions. The following error would have been raised with strict enforcement: Expected X and Y to have the same number of dimensions (got X with dimension 3 and Y with dimension 4).
#   warnings.warn(
# /home/zongchen/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/models/gpytorch.py:129: UserWarning: The model inputs are of type torch.float32. It is strongly recommended to use double precision in BoTorch, as this improves both precision and stability and can help avoid numerical errors. See https://github.com/pytorch/botorch/discussions/1444
#   warnings.warn(_get_single_precision_warning(X.dtype), UserWarning)
# /home/zongchen/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 38
#      36 # Step 7: Optimize the acquisition function to select the next best candidate
#      37 bounds = torch.tensor([[0.0], [10.0]])  # Define bounds for optimization
# ---> 38 candidate, acq_value = optimize_acqf(
#      39     acq_function=one_step_ei,
#      40     bounds=bounds,
#      41     q=1,  # Choosing 1 point for the next evaluation
#      42     num_restarts=5,
#      43     raw_samples=20,
#      44 )
#      46 print("Next candidate point for evaluation:", candidate)
#      47 print("Acquisition value:", acq_value)
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/optim/optimize.py:547, in optimize_acqf(acq_function, bounds, q, num_restarts, raw_samples, options, inequality_constraints, equality_constraints, nonlinear_inequality_constraints, fixed_features, post_processing_func, batch_initial_conditions, return_best_only, gen_candidates, sequential, ic_generator, timeout_sec, return_full_tree, retry_on_optimization_warning, **ic_gen_kwargs)
#     524     gen_candidates = gen_candidates_scipy
#     525 opt_acqf_inputs = OptimizeAcqfInputs(
#     526     acq_function=acq_function,
#     527     bounds=bounds,
#    (...)
#     545     ic_gen_kwargs=ic_gen_kwargs,
#     546 )
# --> 547 return _optimize_acqf(opt_acqf_inputs)
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/optim/optimize.py:569, in _optimize_acqf(opt_inputs)
#     566     return _optimize_acqf_sequential_q(opt_inputs=opt_inputs)
#     568 # Batch optimization (including the case q=1)
# --> 569 return _optimize_acqf_batch(opt_inputs=opt_inputs)
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/optim/optimize.py:341, in _optimize_acqf_batch(opt_inputs)
#     338         batch_acq_values = torch.cat(batch_acq_values_list).flatten()
#     339     return batch_candidates, batch_acq_values, opt_warnings
# --> 341 batch_candidates, batch_acq_values, ws = _optimize_batch_candidates()
#     343 optimization_warning_raised = any(
#     344     (issubclass(w.category, OptimizationWarning) for w in ws)
#     345 )
#     346 if optimization_warning_raised and opt_inputs.retry_on_optimization_warning:
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/optim/optimize.py:325, in _optimize_acqf_batch.<locals>._optimize_batch_candidates()
#     320 with warnings.catch_warnings(record=True) as ws:
#     321     warnings.simplefilter("always", category=OptimizationWarning)
#     322     (
#     323         batch_candidates_curr,
#     324         batch_acq_values_curr,
# --> 325     ) = opt_inputs.gen_candidates(
#     326         batched_ics_, opt_inputs.acq_function, **filtered_gen_kwargs
#     327     )
#     328 opt_warnings += ws
#     329 batch_candidates_list.append(batch_candidates_curr)
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/generation/gen.py:231, in gen_candidates_scipy(initial_conditions, acquisition_function, lower_bounds, upper_bounds, inequality_constraints, equality_constraints, nonlinear_inequality_constraints, options, fixed_features, timeout_sec)
#     228 def f(x):
#     229     return -acquisition_function(x)
# --> 231 res = minimize_with_timeout(
#     232     fun=f_np_wrapper,
#     233     args=(f,),
#     234     x0=x0,
#     235     method=options.get("method", "SLSQP" if constraints else "L-BFGS-B"),
#     236     jac=with_grad,
#     237     bounds=bounds,
#     238     constraints=constraints,
#     239     callback=options.get("callback", None),
#     240     options={
#     241         k: v
#     242         for k, v in options.items()
#     243         if k not in ["method", "callback", "with_grad"]
#     244     },
#     245     timeout_sec=timeout_sec,
#     246 )
#     247 _process_scipy_result(res=res, options=options)
#     249 candidates = fix_features(
#     250     X=torch.from_numpy(res.x).to(initial_conditions).reshape(shapeX),
#     251     fixed_features=fixed_features,
#     252 )
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/optim/utils/timeout.py:80, in minimize_with_timeout(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options, timeout_sec)
#      77     wrapped_callback = callback
#      79 try:
# ---> 80     return optimize.minimize(
#      81         fun=fun,
#      82         x0=x0,
#      83         args=args,
#      84         method=method,
#      85         jac=jac,
#      86         hess=hess,
#      87         hessp=hessp,
#      88         bounds=bounds,
#      89         constraints=constraints,
#      90         tol=tol,
#      91         callback=wrapped_callback,
#      92         options=options,
#      93     )
#      94 except OptimizationTimeoutError as e:
#      95     msg = f"Optimization timed out after {e.runtime} seconds."
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/scipy/optimize/_minimize.py:731, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     728     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     729                              **options)
#     730 elif meth == 'l-bfgs-b':
# --> 731     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     732                            callback=callback, **options)
#     733 elif meth == 'tnc':
#     734     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     735                         **options)
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py:347, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     344         iprint = disp
#     346 # _prepare_scalar_function can use bounds=None to represent no bounds
# --> 347 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     348                               bounds=bounds,
#     349                               finite_diff_rel_step=finite_diff_rel_step)
#     351 func_and_grad = sf.fun_and_grad
#     353 fortran_int = _lbfgsb.types.intvar.dtype
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/scipy/optimize/_optimize.py:288, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     284     bounds = (-np.inf, np.inf)
#     286 # ScalarFunction caches. Reuse of fun(x) during grad
#     287 # calculation reduces overall function evaluations.
# --> 288 sf = ScalarFunction(fun, x0, args, grad, hess,
#     289                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     291 return sf
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:222, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     219     finite_diff_options["as_linear_operator"] = True
#     221 # Initial function evaluation
# --> 222 self._update_fun()
#     224 # Initial gradient evaluation
#     225 self._wrapped_grad, self._ngev = _wrapper_grad(
#     226     grad,
#     227     fun=self._wrapped_fun,
#     228     args=args,
#     229     finite_diff_options=finite_diff_options
#     230 )
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:294, in ScalarFunction._update_fun(self)
#     292 def _update_fun(self):
#     293     if not self.f_updated:
# --> 294         fx = self._wrapped_fun(self.x)
#     295         if fx < self._lowest_f:
#     296             self._lowest_x = self.x
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/scipy/optimize/_optimize.py:79, in MemoizeJac.__call__(self, x, *args)
#      77 def __call__(self, x, *args):
#      78     """ returns the function value """
# ---> 79     self._compute_if_needed(x, *args)
#      80     return self._value
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/scipy/optimize/_optimize.py:73, in MemoizeJac._compute_if_needed(self, x, *args)
#      71 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      72     self.x = np.asarray(x).copy()
# ---> 73     fg = self.fun(x, *args)
#      74     self.jac = fg[1]
#      75     self._value = fg[0]
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/generation/gen.py:189, in gen_candidates_scipy.<locals>.f_np_wrapper(x, f)
#     181 X = (
#     182     torch.from_numpy(x)
#     183     .to(initial_conditions)
#    (...)
#     186     .requires_grad_(True)
#     187 )
#     188 X_fix = fix_features(X, fixed_features=fixed_features)
# --> 189 loss = f(X_fix).sum()
#     190 # compute gradient w.r.t. the inputs (does not accumulate in leaves)
#     191 gradf = _arrayify(torch.autograd.grad(loss, X)[0].contiguous().view(-1))
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/generation/gen.py:229, in gen_candidates_scipy.<locals>.f(x)
#     228 def f(x):
# --> 229     return -acquisition_function(x)
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/utils/transforms.py:320, in concatenate_pending_points.<locals>.decorated(cls, X, **kwargs)
#     318 if cls.X_pending is not None:
#     319     X = torch.cat([X, match_batch_shape(cls.X_pending, X)], dim=-2)
# --> 320 return method(cls, X, **kwargs)
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/utils/transforms.py:277, in t_batch_mode_transform.<locals>.decorator.<locals>.decorated(acqf, X, *args, **kwargs)
#     275 # add t-batch dim
#     276 X = X if X.dim() > 2 else X.unsqueeze(0)
# --> 277 output = method(acqf, X, *args, **kwargs)
#     278 if hasattr(acqf, "model") and is_fully_bayesian(acqf.model):
#     279     output = output.mean(dim=-1)
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/acquisition/monte_carlo.py:266, in SampleReducingMCAcquisitionFunction.forward(self, X)
#     246 @concatenate_pending_points
#     247 @t_batch_mode_transform()
#     248 def forward(self, X: Tensor) -> Tensor:
#     249     r"""Computes the acquisition value associated with the input `X`. Weighs the
#     250     acquisition utility values by smoothed constraint indicators if `constraints`
#     251     was passed to the constructor of the class. Applies `self.sample_reduction` and
#    (...)
#     264         batch shape of model and input `X`.
#     265     """
# --> 266     non_reduced_acqval = self._non_reduced_forward(X=X)
#     267     return self._sample_reduction(self._q_reduction(non_reduced_acqval))
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/acquisition/monte_carlo.py:279, in SampleReducingMCAcquisitionFunction._non_reduced_forward(self, X)
#     269 def _non_reduced_forward(self, X: Tensor) -> Tensor:
#     270     """Compute the constrained acquisition values at the MC-sample, q level.
#     271
#     272     Args:
#    (...)
#     277         A Tensor with shape `sample_sample x batch_shape x q`.
#     278     """
# --> 279     samples, obj = self._get_samples_and_objectives(X)
#     280     acqval = self._sample_forward(obj)  # `sample_sample x batch_shape x q`
#     281     return self._apply_constraints(acqval=acqval, samples=samples)
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/acquisition/monte_carlo.py:114, in MCAcquisitionFunction._get_samples_and_objectives(self, X)
#     103 def _get_samples_and_objectives(self, X: Tensor) -> Tuple[Tensor, Tensor]:
#     104     """Computes posterior samples and objective values at input X.
#     105
#     106     Args:
#    (...)
#     112         tensor of MC objective values with shape `sample_shape x batch_shape x q`.
#     113     """
# --> 114     posterior = self.model.posterior(
#     115         X=X, posterior_transform=self.posterior_transform
#     116     )
#     117     samples = self.get_posterior_samples(posterior)
#     118     return samples, self.objective(samples=samples, X=X)
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/botorch/models/gpytorch.py:379, in BatchedMultiOutputGPyTorchModel.posterior(self, X, output_indices, observation_noise, posterior_transform, **kwargs)
#     375 if self._num_outputs > 1:
#     376     X, output_dim_idx = add_output_dim(
#     377         X=X, original_batch_shape=self._input_batch_shape
#     378     )
# --> 379 mvn = self(X)
#     380 if observation_noise is not False:
#     381     if torch.is_tensor(observation_noise):
#     382         # TODO: Validate noise shape
#     383         # make observation_noise `batch_shape x q x n`
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/gpytorch/models/exact_gp.py:310, in ExactGP.__call__(self, *args, **kwargs)
#     308     train_input = train_input.expand(*batch_shape, *train_input.shape[-2:])
#     309 if batch_shape != input.shape[:-2]:
# --> 310     batch_shape = torch.broadcast_shapes(batch_shape, input.shape[:-2])
#     311     train_input = train_input.expand(*batch_shape, *train_input.shape[-2:])
#     312     input = input.expand(*batch_shape, *input.shape[-2:])
#
# File ~/miniconda3/envs/look_ahead_bo/lib/python3.10/site-packages/torch/functional.py:133, in broadcast_shapes(*shapes)
#     131             continue
#     132         if result[i] != 1:
# --> 133             raise RuntimeError("Shape mismatch: objects cannot be broadcast to a single shape")
#     134         result[i] = shape[i]
#     135 else:
#
# RuntimeError: Shape mismatch: objects cannot be broadcast to a single shape

# %%
fantasy_model.train_targets.shape
# Out:
# torch.Size([1, 20, 11])
